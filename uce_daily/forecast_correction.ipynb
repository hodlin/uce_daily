# %%
import datetime as dt

from forecast_correction import add_correction, get_corrections_list

# %%
from sqlalchemy import create_engine, MetaData
from sqlalchemy.pool import NullPool
from settings.db import FORECAST_DB_URL

engine = create_engine(FORECAST_DB_URL, poolclass=NullPool)
metadata = MetaData()
metadata.reflect(bind=engine)
# Out:
# C:\Users\o.babenko\.conda\envs\uce_daily\lib\site-packages\ipykernel_launcher.py:7: SAWarning: Did not recognize type 'point' of column 'location'
#   import sys
# Exception during reset or similar
# Traceback (most recent call last):
#   File "C:\Users\o.babenko\.conda\envs\uce_daily\lib\site-packages\sqlalchemy\pool\base.py", line 739, in _finalize_fairy
#     fairy._reset(pool)
#   File "C:\Users\o.babenko\.conda\envs\uce_daily\lib\site-packages\sqlalchemy\pool\base.py", line 988, in _reset
#     pool._dialect.do_rollback(self)
#   File "C:\Users\o.babenko\.conda\envs\uce_daily\lib\site-packages\sqlalchemy\engine\default.py", line 682, in do_rollback
#     dbapi_connection.rollback()
# psycopg2.OperationalError: server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.
# server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# ...

# %%
start_time = dt.datetime(year=2022, month=7, day=4, hour=4, minute=0)
end_time = dt.datetime(year=2022, month=7, day=4, hour=22, minute=0)

# Cluster #1
add_correction('Pohrebyshche',   start_time, end_time, 'factor', factor=1.25, level=None, engine=engine, metadata=metadata) # 1.1/1.15
add_correction('Pohrebyshche',   start_time, end_time, 'cut', factor=None, level=9050, engine=engine, metadata=metadata)
add_correction('Bilashky',       start_time, end_time, 'factor', factor=1.25,  level=None, engine=engine, metadata=metadata) # 1.1/1.15
add_correction('Bilashky',       start_time, end_time, 'cut', factor=None, level=6050, engine=engine, metadata=metadata)

# Cluster #2
add_correction('Bar',            start_time, end_time, 'factor', factor=1.35, level=None, engine=engine, metadata=metadata)
add_correction('Bar',            start_time, end_time, 'cut', factor=None, level=6000, engine=engine, metadata=metadata)
add_correction('Balky',          start_time, end_time, 'factor', factor=1.35, level=None, engine=engine, metadata=metadata)
add_correction('Balky',          start_time, end_time, 'cut', factor=None, level=7000, engine=engine, metadata=metadata)
add_correction('Verkhivka',      start_time, end_time, 'factor', factor=1.35, level=None, engine=engine, metadata=metadata)
add_correction('Verkhivka',      start_time, end_time, 'cut', factor=None, level=2600, engine=engine, metadata=metadata)
add_correction('Kopaihorod',     start_time, end_time, 'factor', factor=1.35, level=None, engine=engine, metadata=metadata)
add_correction('Kopaihorod',     start_time, end_time, 'cut', factor=None, level=6000, engine=engine, metadata=metadata)
add_correction('Stanislavchyk',  start_time, end_time, 'factor', factor=1.35, level=None, engine=engine, metadata=metadata) #1.22/1.15
add_correction('Stanislavchyk',  start_time, end_time, 'cut', factor=None, level=7900, engine=engine, metadata=metadata)
add_correction('Sharhorod_1',    start_time, end_time, 'factor', factor=1.35, level=None, engine=engine, metadata=metadata)
add_correction('Sharhorod_1',    start_time, end_time, 'cut', factor=None, level=7000, engine=engine, metadata=metadata)

# Cluster #3
add_correction('Hnatkiv',        start_time, end_time, 'factor', factor=1.45, level=None, engine=engine, metadata=metadata)
add_correction('Hnatkiv',        start_time, end_time, 'cut', factor=None, level=4600, engine=engine, metadata=metadata)
add_correction('Porohy',         start_time, end_time, 'factor', factor=1.4, level=None, engine=engine, metadata=metadata)
add_correction('Porohy',         start_time, end_time, 'cut', factor=None, level=4000, engine=engine, metadata=metadata)

# Cluster #4
add_correction('Hlybochok_1',    start_time, end_time, 'factor', factor=1.45, level=None, engine=engine, metadata=metadata)
add_correction('Hlybochok_1',    start_time, end_time, 'cut', factor=None, level=1260, engine=engine, metadata=metadata)
add_correction('Hlybochok_2.1',  start_time, end_time, 'factor', factor=1.45, level=None, engine=engine, metadata=metadata)
add_correction('Hlybochok_2.1',  start_time, end_time, 'cut', factor=None, level=2260, engine=engine, metadata=metadata)
add_correction('Hlybochok_2.2',  start_time, end_time, 'factor', factor=1.35, level=None, engine=engine, metadata=metadata) #1.2
add_correction('Hlybochok_2.2',  start_time, end_time, 'cut', factor=None, level=3200, engine=engine, metadata=metadata)
add_correction('Cherniatka',     start_time, end_time, 'factor', factor=1.4, level=None, engine=engine, metadata=metadata)
add_correction('Cherniatka',     start_time, end_time, 'cut', factor=None, level=7000, engine=engine, metadata=metadata)
add_correction('Chechelnyk_1',   start_time, end_time, 'factor', factor=1.25, level=None, engine=engine, metadata=metadata) #1.15
add_correction('Chechelnyk_1',   start_time, end_time, 'cut', factor=None, level=7820, engine=engine, metadata=metadata)
add_correction('Chechelnyk_2',   start_time, end_time, 'factor', factor=1.25, level=None, engine=engine, metadata=metadata) #1.15
add_correction('Chechelnyk_2',   start_time, end_time, 'cut', factor=None, level=7900, engine=engine, metadata=metadata)

# Cluster #5
add_correction('Komyshany_1',    start_time, end_time, 'factor', factor=1.2, level=None, engine=engine, metadata=metadata)
add_correction('Komyshany_1',    start_time, end_time, 'cut', factor=None, level=4900, engine=engine, metadata=metadata)
add_correction('Komyshany_2',    start_time, end_time, 'factor', factor=1.15, level=None, engine=engine, metadata=metadata)
add_correction('Komyshany_2',    start_time, end_time, 'cut', factor=None, level=4000, engine=engine, metadata=metadata)
add_correction('Bilozerka',      start_time, end_time, 'factor', factor=1.15, level=None, engine=engine, metadata=metadata)
add_correction('Bilozerka',      start_time, end_time, 'cut', factor=None, level=9000, engine=engine, metadata=metadata)
add_correction('Myroliubivka',   start_time, end_time, 'cut', factor=None, level=0, engine=engine, metadata=metadata)
add_correction('Kyselivka',      start_time, end_time, 'cut', factor=None, level=0, engine=engine, metadata=metadata)
 
# Cluster #6
add_correction('Oleshky_1',      start_time, end_time, 'factor', factor=1.1, level=None, engine=engine, metadata=metadata)
add_correction('Oleshky_1',      start_time, end_time, 'cut', factor=None, level=16000, engine=engine, metadata=metadata)
add_correction('Oleshky_2',      start_time, end_time, 'factor', factor=1.1, level=None, engine=engine, metadata=metadata)
add_correction('Oleshky_2',      start_time, end_time, 'cut', factor=None, level=15000, engine=engine, metadata=metadata)
add_correction('Poniativka',     start_time, end_time, 'factor', factor=1.15, level=None, engine=engine, metadata=metadata)
add_correction('Poniativka',     start_time, end_time, 'cut', factor=None, level=14500, engine=engine, metadata=metadata)
add_correction('Kostohryzove',   start_time, end_time, 'factor', factor=1.2, level=None, engine=engine, metadata=metadata)
add_correction('Kostohryzove',   start_time, end_time, 'cut', factor=None, level=14500, engine=engine, metadata=metadata)

# Cluster #7
add_correction('Veliton',        start_time, end_time, 'factor', factor=1.35, level=None, engine=engine, metadata=metadata)
add_correction('Veliton',        start_time, end_time, 'cut', factor=None, level=2300, engine=engine, metadata=metadata)
add_correction('Velihen',        start_time, end_time, 'factor', factor=1.3, level=None, engine=engine, metadata=metadata) #+3% from Veliton
add_correction('Velihen',        start_time, end_time, 'cut', factor=None, level=5500, engine=engine, metadata=metadata)

# Cluster #8
add_correction('Mykolaivka',     start_time, end_time, 'factor', factor=1.25, level=None, engine=engine, metadata=metadata)
add_correction('Mykolaivka',     start_time, end_time, 'cut', factor=None, level=4500, engine=engine, metadata=metadata)
add_correction('Rubanivka',      start_time, end_time, 'factor', factor=1.3, level=None, engine=engine, metadata=metadata)
add_correction('Rubanivka',      start_time, end_time, 'cut', factor=None, level=16000, engine=engine, metadata=metadata)
add_correction('Mala_Lepetykha', start_time, end_time, 'factor', factor=1.2, level=None, engine=engine, metadata=metadata)
add_correction('Mala_Lepetykha', start_time, end_time, 'cut', factor=None, level=4750, engine=engine, metadata=metadata)
add_correction('Kachkarivka',    start_time, end_time, 'factor', factor=0.8, level=None, engine=engine, metadata=metadata)
add_correction('Kachkarivka',    start_time, end_time, 'cut', factor=None, level=3500, engine=engine, metadata=metadata)

# Cluster #9
add_correction('Liubymivka',     start_time, end_time, 'factor', factor=1.15, level=None, engine=engine, metadata=metadata)
add_correction('Liubymivka',     start_time, end_time, 'cut', factor=None, level=9000, engine=engine, metadata=metadata)
add_correction('Vasylivka',      start_time, end_time, 'factor', factor=1.15, level=None, engine=engine, metadata=metadata)
add_correction('Vasylivka',      start_time, end_time, 'cut', factor=None, level=38000, engine=engine, metadata=metadata)

# Cluster #14
add_correction('Kulevcha',       start_time, end_time, 'factor', factor=1.3, level=None, engine=engine, metadata=metadata) #1.13
add_correction('Kulevcha',       start_time, end_time, 'cut', factor=None, level=7900, engine=engine, metadata=metadata)

# Cluster #10
add_correction('Dibrovka',       start_time, end_time, 'factor', factor=1.25, level=None, engine=engine, metadata=metadata)
add_correction('Dibrovka',       start_time, end_time, 'cut', factor=None, level=15000, engine=engine, metadata=metadata)
add_correction('Yelanets_1',     start_time, end_time, 'factor', factor=1.15, level=None, engine=engine, metadata=metadata)
add_correction('Yelanets_1',     start_time, end_time, 'cut', factor=None, level=10000, engine=engine, metadata=metadata)
add_correction('Yelanets_2',     start_time, end_time, 'factor', factor=1.15, level=None, engine=engine, metadata=metadata)
add_correction('Yelanets_2',     start_time, end_time, 'cut', factor=None, level=5000, engine=engine, metadata=metadata)

# Cluster #11
add_correction('Afanasiivka',    start_time, end_time, 'cut', factor=None, level=0, engine=engine, metadata=metadata)
add_correction('Bazaltova',      start_time, end_time, 'cut', factor=None, level=0, engine=engine, metadata=metadata)
add_correction('Novokondakove',  start_time, end_time, 'cut', factor=None, level=0, engine=engine, metadata=metadata)
add_correction('Inhulets_1',     start_time, end_time, 'cut', factor=None, level=0, engine=engine, metadata=metadata)
add_correction('Inhulets_2',     start_time, end_time, 'cut', factor=None, level=0, engine=engine, metadata=metadata)
add_correction('Bereznehuvate',  start_time, end_time, 'cut', factor=None, level=1500, engine=engine, metadata=metadata)

# Cluster #12
add_correction('Teplychna',      start_time, end_time, 'factor', factor=1.15, level=None, engine=engine, metadata=metadata)
add_correction('Teplychna',      start_time, end_time, 'cut', factor=None, level=10200, engine=engine, metadata=metadata)

# Cluster #13
add_correction('Balivka',        start_time, end_time, 'factor', factor=1.2, level=None, engine=engine, metadata=metadata) #1.15
add_correction('Balivka',        start_time, end_time, 'cut', factor=None, level=16100, engine=engine, metadata=metadata)
add_correction('Solone',         start_time, end_time, 'factor', factor=1.2, level=None, engine=engine, metadata=metadata) #1.2
add_correction('Solone',         start_time, end_time, 'cut', factor=None, level=10000, engine=engine, metadata=metadata)
add_correction('Stepnohirsk',    start_time, end_time, 'cut', factor=None, level=0, engine=engine, metadata=metadata)
# Out:
# {'id': 7739, 'site': 33, 'type': 'factor', 'factor': 1.25, 'level': None, 'date': datetime.date(2022, 7, 4), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-07-03T15:46:59.263344+00:00\n'}
# {'id': 7740, 'site': 33, 'type': 'cut', 'factor': None, 'level': 9050, 'date': datetime.date(2022, 7, 4), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-07-03T15:46:59.950042+00:00\n'}
# {'id': 7741, 'site': 34, 'type': 'factor', 'factor': 1.25, 'level': None, 'date': datetime.date(2022, 7, 4), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-07-03T15:47:00.613136+00:00\n'}
# ...

# %%
from settings.sites import ceg as sites_list

start_time = dt.datetime(year=2022, month=7, day=1, hour=13, minute=0)
end_time = dt.datetime(year=2022, month=7, day=1, hour=22, minute=0)

# add_correction('Poniativka', start_time, end_time, 'factor', factor=1.2, level=None, repeat=True, engine=engine, metadata=metadata)
# add_correction('Vasylivka', start_time, end_time, 'cut', factor=None, level=1, repeat=True, engine=engine, metadata=metadata)
# add_correction('Stanislavchyk', start_time, end_time, 'cut', factor=None, level=1000, repeat=True, engine=engine, metadata=metadata)
# add_correction('Oleshky_2', start_time, end_time, 'factor', factor=0.5, level=None, repeat=True, engine=engine, metadata=metadata)
# add_correction('Bar', start_time, end_time, 'cut', factor=None, level=5000, repeat=True, engine=engine, metadata=metadata)
# add_correction('Balky', start_time, end_time, 'cut', factor=None, level=6000, repeat=True, engine=engine, metadata=metadata)
# add_correction('Bilozerka', start_time, end_time, 'cut', factor=None, level=0, repeat=True, engine=engine, metadata=metadata)
# add_correction('Yelanets_1', start_time, end_time, 'cut', factor=None, level=2000, repeat=True, engine=engine, metadata=metadata)
# add_correction('Yelanets_2', start_time, end_time, 'cut', factor=None, level=2000, repeat=True, engine=engine, metadata=metadata)
# add_correction('Oleshky_1', start_time, end_time, 'factor', factor=0.6, level=None, repeat=True, engine=engine, metadata=metadata)
# add_correction('Oleshky_2', start_time, end_time, 'factor', factor=0.55, level=None, repeat=True, engine=engine, metadata=metadata)

# %%
correction_list = get_corrections_list(dt.date(year=2022, month=7, day=4), type='=', engine=engine, metadata=metadata)
for correction in correction_list:
    print(correction[:6])
# Out:
# ('Pohrebyshche', 7739, 33, 'factor', 1.25, None)
# ('Pohrebyshche', 7740, 33, 'cut', None, 9050)
# ('Bilashky', 7741, 34, 'factor', 1.25, None)
# ('Bilashky', 7742, 34, 'cut', None, 6050)
# ('Bar', 7743, 5, 'factor', 1.35, None)
# ('Bar', 7744, 5, 'cut', None, 6000)
# ('Balky', 7745, 7, 'factor', 1.35, None)
# ('Balky', 7746, 7, 'cut', None, 7000)
# ('Verkhivka', 7747, 6, 'factor', 1.35, None)
# ('Verkhivka', 7748, 6, 'cut', None, 2600)
# ('Kopaihorod', 7749, 13, 'factor', 1.35, None)
# ('Kopaihorod', 7750, 13, 'cut', None, 6000)
# ('Stanislavchyk', 7751, 12, 'factor', 1.35, None)
# ('Stanislavchyk', 7752, 12, 'cut', None, 7900)
# ('Sharhorod_1', 7753, 8, 'factor', 1.35, None)
# ('Sharhorod_1', 7754, 8, 'cut', None, 7000)
# ('Hnatkiv', 7755, 50, 'factor', 1.45, None)
# ('Hnatkiv', 7756, 50, 'cut', None, 4600)
# ('Porohy', 7757, 48, 'factor', 1.4, None)
# ('Porohy', 7758, 48, 'cut', None, 4000)
# ('Hlybochok_1', 7759, 16, 'factor', 1.45, None)
# ...
