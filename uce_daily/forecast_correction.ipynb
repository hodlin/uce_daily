# %%
import datetime as dt

from forecast_correction import add_correction, get_corrections_list

# %%
from sqlalchemy import create_engine, MetaData
from sqlalchemy.pool import NullPool
from settings.db import FORECAST_DB_URL

engine = create_engine(FORECAST_DB_URL, poolclass=NullPool)
metadata = MetaData()
metadata.reflect(bind=engine)
# Out:
# C:\Users\o.babenko\.conda\envs\uce_daily\lib\site-packages\ipykernel_launcher.py:7: SAWarning: Did not recognize type 'point' of column 'location'
#   import sys

# %%
start_time = dt.datetime(year=2022, month=6, day=28, hour=4, minute=0)
end_time = dt.datetime(year=2022, month=6, day=28, hour=22, minute=0)

# Cluster #1
add_correction('Pohrebyshche',   start_time, end_time, 'factor', factor=1.1, level=None, engine=engine, metadata=metadata) # 1.1
add_correction('Pohrebyshche',   start_time, end_time, 'cut', factor=None, level=9050, engine=engine, metadata=metadata)
add_correction('Bilashky',       start_time, end_time, 'factor', factor=1.05,  level=None, engine=engine, metadata=metadata) # 1.1
add_correction('Bilashky',       start_time, end_time, 'cut', factor=None, level=6050, engine=engine, metadata=metadata)

# Cluster #2
add_correction('Bar',            start_time, end_time, 'factor', factor=1.15, level=None, engine=engine, metadata=metadata)
add_correction('Bar',            start_time, end_time, 'cut', factor=None, level=6000, engine=engine, metadata=metadata)
add_correction('Balky',          start_time, end_time, 'factor', factor=1.1, level=None, engine=engine, metadata=metadata)
add_correction('Balky',          start_time, end_time, 'cut', factor=None, level=7000, engine=engine, metadata=metadata)
add_correction('Verkhivka',      start_time, end_time, 'factor', factor=1.15, level=None, engine=engine, metadata=metadata)
add_correction('Verkhivka',      start_time, end_time, 'cut', factor=None, level=2600, engine=engine, metadata=metadata)
add_correction('Kopaihorod',     start_time, end_time, 'factor', factor=1.05, level=None, engine=engine, metadata=metadata)
add_correction('Kopaihorod',     start_time, end_time, 'cut', factor=None, level=6000, engine=engine, metadata=metadata)
add_correction('Stanislavchyk',  start_time, end_time, 'factor', factor=1.05, level=None, engine=engine, metadata=metadata) #1.22
add_correction('Stanislavchyk',  start_time, end_time, 'cut', factor=None, level=7900, engine=engine, metadata=metadata)
add_correction('Sharhorod_1',    start_time, end_time, 'factor', factor=1.15, level=None, engine=engine, metadata=metadata)
add_correction('Sharhorod_1',    start_time, end_time, 'cut', factor=None, level=7000, engine=engine, metadata=metadata)

# Cluster #3
add_correction('Hnatkiv',        start_time, end_time, 'factor', factor=1.25, level=None, engine=engine, metadata=metadata)
add_correction('Hnatkiv',        start_time, end_time, 'cut', factor=None, level=4600, engine=engine, metadata=metadata)
add_correction('Porohy',         start_time, end_time, 'factor', factor=1.2, level=None, engine=engine, metadata=metadata)
add_correction('Porohy',         start_time, end_time, 'cut', factor=None, level=4000, engine=engine, metadata=metadata)

# Cluster #4
add_correction('Hlybochok_1',    start_time, end_time, 'factor', factor=1.2, level=None, engine=engine, metadata=metadata)
add_correction('Hlybochok_1',    start_time, end_time, 'cut', factor=None, level=1370, engine=engine, metadata=metadata)
add_correction('Hlybochok_2.1',  start_time, end_time, 'factor', factor=1.2, level=None, engine=engine, metadata=metadata)
add_correction('Hlybochok_2.1',  start_time, end_time, 'cut', factor=None, level=2470, engine=engine, metadata=metadata)
add_correction('Hlybochok_2.2',  start_time, end_time, 'factor', factor=1.1, level=None, engine=engine, metadata=metadata) #1.2
add_correction('Hlybochok_2.2',  start_time, end_time, 'cut', factor=None, level=3200, engine=engine, metadata=metadata)
add_correction('Cherniatka',     start_time, end_time, 'factor', factor=1.2, level=None, engine=engine, metadata=metadata)
add_correction('Cherniatka',     start_time, end_time, 'cut', factor=None, level=7000, engine=engine, metadata=metadata)
add_correction('Chechelnyk_1',   start_time, end_time, 'factor', factor=1.05, level=None, engine=engine, metadata=metadata)
add_correction('Chechelnyk_1',   start_time, end_time, 'cut', factor=None, level=7820, engine=engine, metadata=metadata)
add_correction('Chechelnyk_2',   start_time, end_time, 'factor', factor=1.05, level=None, engine=engine, metadata=metadata)
add_correction('Chechelnyk_2',   start_time, end_time, 'cut', factor=None, level=7900, engine=engine, metadata=metadata)

# Cluster #5
add_correction('Komyshany_1',    start_time, end_time, 'factor', factor=1.25, level=None, engine=engine, metadata=metadata)
add_correction('Komyshany_1',    start_time, end_time, 'cut', factor=None, level=4900, engine=engine, metadata=metadata)
add_correction('Komyshany_2',    start_time, end_time, 'factor', factor=1.2, level=None, engine=engine, metadata=metadata)
add_correction('Komyshany_2',    start_time, end_time, 'cut', factor=None, level=4000, engine=engine, metadata=metadata)
add_correction('Bilozerka',      start_time, end_time, 'factor', factor=1.2, level=None, engine=engine, metadata=metadata)
add_correction('Bilozerka',      start_time, end_time, 'cut', factor=None, level=9000, engine=engine, metadata=metadata)
add_correction('Myroliubivka',   start_time, end_time, 'cut', factor=None, level=0, engine=engine, metadata=metadata)
add_correction('Kyselivka',      start_time, end_time, 'cut', factor=None, level=0, engine=engine, metadata=metadata)
 
# Cluster #6
add_correction('Oleshky_1',      start_time, end_time, 'factor', factor=1.15, level=None, engine=engine, metadata=metadata)
add_correction('Oleshky_1',      start_time, end_time, 'cut', factor=None, level=16000, engine=engine, metadata=metadata)
add_correction('Oleshky_2',      start_time, end_time, 'factor', factor=1.15, level=None, engine=engine, metadata=metadata)
add_correction('Oleshky_2',      start_time, end_time, 'cut', factor=None, level=15000, engine=engine, metadata=metadata)
add_correction('Poniativka',     start_time, end_time, 'factor', factor=1.15, level=None, engine=engine, metadata=metadata)
add_correction('Poniativka',     start_time, end_time, 'cut', factor=None, level=14500, engine=engine, metadata=metadata)
add_correction('Kostohryzove',   start_time, end_time, 'factor', factor=1.3, level=None, engine=engine, metadata=metadata)
add_correction('Kostohryzove',   start_time, end_time, 'cut', factor=None, level=14500, engine=engine, metadata=metadata)

# Cluster #7
add_correction('Veliton',        start_time, end_time, 'factor', factor=1.75, level=None, engine=engine, metadata=metadata)
add_correction('Veliton',        start_time, end_time, 'cut', factor=None, level=2300, engine=engine, metadata=metadata)
add_correction('Velihen',        start_time, end_time, 'factor', factor=1.7, level=None, engine=engine, metadata=metadata) #+3% from Veliton
add_correction('Velihen',        start_time, end_time, 'cut', factor=None, level=5500, engine=engine, metadata=metadata)

# Cluster #8
add_correction('Mykolaivka',     start_time, end_time, 'factor', factor=1.25, level=None, engine=engine, metadata=metadata)
add_correction('Mykolaivka',     start_time, end_time, 'cut', factor=None, level=4300, engine=engine, metadata=metadata)
add_correction('Rubanivka',      start_time, end_time, 'factor', factor=1.35, level=None, engine=engine, metadata=metadata)
add_correction('Rubanivka',      start_time, end_time, 'cut', factor=None, level=16000, engine=engine, metadata=metadata)
add_correction('Mala_Lepetykha', start_time, end_time, 'factor', factor=1.2, level=None, engine=engine, metadata=metadata)
add_correction('Mala_Lepetykha', start_time, end_time, 'cut', factor=None, level=4750, engine=engine, metadata=metadata)
add_correction('Kachkarivka',    start_time, end_time, 'factor', factor=0.8, level=None, engine=engine, metadata=metadata)
add_correction('Kachkarivka',    start_time, end_time, 'cut', factor=None, level=3500, engine=engine, metadata=metadata)

# Cluster #9
add_correction('Liubymivka',     start_time, end_time, 'factor', factor=1.25, level=None, engine=engine, metadata=metadata)
add_correction('Liubymivka',     start_time, end_time, 'cut', factor=None, level=9000, engine=engine, metadata=metadata)
add_correction('Vasylivka',      start_time, end_time, 'factor', factor=1.25, level=None, engine=engine, metadata=metadata)
add_correction('Vasylivka',      start_time, end_time, 'cut', factor=None, level=38000, engine=engine, metadata=metadata)

# Cluster #14
add_correction('Kulevcha',       start_time, end_time, 'factor', factor=1.25, level=None, engine=engine, metadata=metadata) #1.13
add_correction('Kulevcha',       start_time, end_time, 'cut', factor=None, level=7900, engine=engine, metadata=metadata)

# Cluster #10
add_correction('Dibrovka',       start_time, end_time, 'factor', factor=1.15, level=None, engine=engine, metadata=metadata)
add_correction('Dibrovka',       start_time, end_time, 'cut', factor=None, level=16500, engine=engine, metadata=metadata)
add_correction('Yelanets_1',     start_time, end_time, 'factor', factor=1.1, level=None, engine=engine, metadata=metadata)
add_correction('Yelanets_1',     start_time, end_time, 'cut', factor=None, level=10000, engine=engine, metadata=metadata)
add_correction('Yelanets_2',     start_time, end_time, 'factor', factor=1.1, level=None, engine=engine, metadata=metadata)
add_correction('Yelanets_2',     start_time, end_time, 'cut', factor=None, level=5000, engine=engine, metadata=metadata)

# Cluster #11
add_correction('Afanasiivka',    start_time, end_time, 'cut', factor=None, level=0, engine=engine, metadata=metadata)
add_correction('Bazaltova',      start_time, end_time, 'cut', factor=None, level=0, engine=engine, metadata=metadata)
add_correction('Novokondakove',  start_time, end_time, 'cut', factor=None, level=0, engine=engine, metadata=metadata)
add_correction('Inhulets_1',     start_time, end_time, 'cut', factor=None, level=0, engine=engine, metadata=metadata)
add_correction('Inhulets_2',     start_time, end_time, 'cut', factor=None, level=0, engine=engine, metadata=metadata)
add_correction('Bereznehuvate',  start_time, end_time, 'cut', factor=None, level=1500, engine=engine, metadata=metadata)

# Cluster #12
add_correction('Teplychna',      start_time, end_time, 'factor', factor=1.35, level=None, engine=engine, metadata=metadata)
add_correction('Teplychna',      start_time, end_time, 'cut', factor=None, level=10200, engine=engine, metadata=metadata)

# Cluster #13
add_correction('Balivka',        start_time, end_time, 'factor', factor=1.05, level=None, engine=engine, metadata=metadata)
add_correction('Balivka',        start_time, end_time, 'cut', factor=None, level=16100, engine=engine, metadata=metadata)
add_correction('Solone',         start_time, end_time, 'factor', factor=1.05, level=None, engine=engine, metadata=metadata)
add_correction('Solone',         start_time, end_time, 'cut', factor=None, level=10000, engine=engine, metadata=metadata)
add_correction('Stepnohirsk',    start_time, end_time, 'cut', factor=None, level=0, engine=engine, metadata=metadata)
# Out:
# {'id': 7223, 'site': 33, 'type': 'factor', 'factor': 1.1, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:04.592420+00:00\n'}
# {'id': 7224, 'site': 33, 'type': 'cut', 'factor': None, 'level': 9050, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:05.268467+00:00\n'}
# {'id': 7225, 'site': 34, 'type': 'factor', 'factor': 1.05, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:05.947891+00:00\n'}
# {'id': 7226, 'site': 34, 'type': 'cut', 'factor': None, 'level': 6050, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:06.623908+00:00\n'}
# {'id': 7227, 'site': 5, 'type': 'factor', 'factor': 1.15, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:07.289037+00:00\n'}
# {'id': 7228, 'site': 5, 'type': 'cut', 'factor': None, 'level': 6000, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:07.947981+00:00\n'}
# {'id': 7229, 'site': 7, 'type': 'factor', 'factor': 1.1, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:08.609826+00:00\n'}
# {'id': 7230, 'site': 7, 'type': 'cut', 'factor': None, 'level': 7000, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:09.284059+00:00\n'}
# {'id': 7231, 'site': 6, 'type': 'factor', 'factor': 1.15, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:09.936405+00:00\n'}
# {'id': 7232, 'site': 6, 'type': 'cut', 'factor': None, 'level': 2600, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:10.596402+00:00\n'}
# {'id': 7233, 'site': 13, 'type': 'factor', 'factor': 1.05, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:11.256293+00:00\n'}
# {'id': 7234, 'site': 13, 'type': 'cut', 'factor': None, 'level': 6000, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:11.935393+00:00\n'}
# {'id': 7235, 'site': 12, 'type': 'factor', 'factor': 1.05, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:12.614212+00:00\n'}
# {'id': 7236, 'site': 12, 'type': 'cut', 'factor': None, 'level': 7900, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:13.273384+00:00\n'}
# {'id': 7237, 'site': 8, 'type': 'factor', 'factor': 1.15, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:13.938127+00:00\n'}
# {'id': 7238, 'site': 8, 'type': 'cut', 'factor': None, 'level': 7000, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:14.590806+00:00\n'}
# {'id': 7239, 'site': 50, 'type': 'factor', 'factor': 1.25, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:15.245857+00:00\n'}
# {'id': 7240, 'site': 50, 'type': 'cut', 'factor': None, 'level': 4600, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:15.914324+00:00\n'}
# {'id': 7241, 'site': 48, 'type': 'factor', 'factor': 1.2, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:16.585425+00:00\n'}
# {'id': 7242, 'site': 48, 'type': 'cut', 'factor': None, 'level': 4000, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:17.243943+00:00\n'}
# {'id': 7243, 'site': 16, 'type': 'factor', 'factor': 1.2, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:17.902775+00:00\n'}
# {'id': 7244, 'site': 16, 'type': 'cut', 'factor': None, 'level': 1370, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:18.574088+00:00\n'}
# {'id': 7245, 'site': 17, 'type': 'factor', 'factor': 1.2, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:19.299045+00:00\n'}
# {'id': 7246, 'site': 17, 'type': 'cut', 'factor': None, 'level': 2470, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:19.958238+00:00\n'}
# {'id': 7247, 'site': 18, 'type': 'factor', 'factor': 1.1, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:20.619739+00:00\n'}
# {'id': 7248, 'site': 18, 'type': 'cut', 'factor': None, 'level': 3200, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:21.282152+00:00\n'}
# {'id': 7249, 'site': 14, 'type': 'factor', 'factor': 1.2, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:21.966180+00:00\n'}
# {'id': 7250, 'site': 14, 'type': 'cut', 'factor': None, 'level': 7000, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:22.662165+00:00\n'}
# {'id': 7251, 'site': 10, 'type': 'factor', 'factor': 1.05, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:23.336621+00:00\n'}
# {'id': 7252, 'site': 10, 'type': 'cut', 'factor': None, 'level': 7820, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:24.002585+00:00\n'}
# {'id': 7253, 'site': 11, 'type': 'factor', 'factor': 1.05, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:24.679529+00:00\n'}
# {'id': 7254, 'site': 11, 'type': 'cut', 'factor': None, 'level': 7900, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:25.347481+00:00\n'}
# {'id': 7255, 'site': 20, 'type': 'factor', 'factor': 1.25, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:26.012533+00:00\n'}
# {'id': 7256, 'site': 20, 'type': 'cut', 'factor': None, 'level': 4900, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:26.686297+00:00\n'}
# {'id': 7257, 'site': 21, 'type': 'factor', 'factor': 1.2, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:27.359451+00:00\n'}
# {'id': 7258, 'site': 21, 'type': 'cut', 'factor': None, 'level': 4000, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:28.044680+00:00\n'}
# {'id': 7259, 'site': 15, 'type': 'factor', 'factor': 1.2, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:28.710666+00:00\n'}
# {'id': 7260, 'site': 15, 'type': 'cut', 'factor': None, 'level': 9000, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:29.384308+00:00\n'}
# {'id': 7261, 'site': 1, 'type': 'cut', 'factor': None, 'level': 0, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:30.041810+00:00\n'}
# {'id': 7262, 'site': 3, 'type': 'cut', 'factor': None, 'level': 0, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:30.701663+00:00\n'}
# {'id': 7263, 'site': 28, 'type': 'factor', 'factor': 1.15, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:31.384486+00:00\n'}
# {'id': 7264, 'site': 28, 'type': 'cut', 'factor': None, 'level': 16000, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:32.060043+00:00\n'}
# {'id': 7265, 'site': 27, 'type': 'factor', 'factor': 1.15, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:32.734208+00:00\n'}
# {'id': 7266, 'site': 27, 'type': 'cut', 'factor': None, 'level': 15000, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:33.406731+00:00\n'}
# {'id': 7267, 'site': 4, 'type': 'factor', 'factor': 1.15, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:34.099504+00:00\n'}
# {'id': 7268, 'site': 4, 'type': 'cut', 'factor': None, 'level': 14500, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:34.826541+00:00\n'}
# {'id': 7269, 'site': 9, 'type': 'factor', 'factor': 1.3, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:35.487359+00:00\n'}
# {'id': 7270, 'site': 9, 'type': 'cut', 'factor': None, 'level': 14500, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:36.132028+00:00\n'}
# {'id': 7271, 'site': 24, 'type': 'factor', 'factor': 1.75, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:36.791619+00:00\n'}
# {'id': 7272, 'site': 24, 'type': 'cut', 'factor': None, 'level': 2300, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:37.462879+00:00\n'}
# {'id': 7273, 'site': 23, 'type': 'factor', 'factor': 1.7, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:38.128307+00:00\n'}
# {'id': 7274, 'site': 23, 'type': 'cut', 'factor': None, 'level': 5500, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:38.792453+00:00\n'}
# {'id': 7275, 'site': 19, 'type': 'factor', 'factor': 1.25, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:39.453098+00:00\n'}
# {'id': 7276, 'site': 19, 'type': 'cut', 'factor': None, 'level': 4300, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:40.112531+00:00\n'}
# {'id': 7277, 'site': 26, 'type': 'factor', 'factor': 1.35, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:40.773878+00:00\n'}
# {'id': 7278, 'site': 26, 'type': 'cut', 'factor': None, 'level': 16000, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:41.427764+00:00\n'}
# {'id': 7279, 'site': 25, 'type': 'factor', 'factor': 1.2, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:42.087039+00:00\n'}
# {'id': 7280, 'site': 25, 'type': 'cut', 'factor': None, 'level': 4750, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:42.763400+00:00\n'}
# {'id': 7281, 'site': 47, 'type': 'factor', 'factor': 0.8, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:43.441044+00:00\n'}
# {'id': 7282, 'site': 47, 'type': 'cut', 'factor': None, 'level': 3500, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:44.101041+00:00\n'}
# {'id': 7283, 'site': 31, 'type': 'factor', 'factor': 1.25, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:44.765365+00:00\n'}
# {'id': 7284, 'site': 31, 'type': 'cut', 'factor': None, 'level': 9000, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:45.433084+00:00\n'}
# {'id': 7285, 'site': 46, 'type': 'factor', 'factor': 1.25, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:46.109173+00:00\n'}
# {'id': 7286, 'site': 46, 'type': 'cut', 'factor': None, 'level': 38000, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:46.757662+00:00\n'}
# {'id': 7287, 'site': 49, 'type': 'factor', 'factor': 1.25, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:47.406927+00:00\n'}
# {'id': 7288, 'site': 49, 'type': 'cut', 'factor': None, 'level': 7900, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:48.075920+00:00\n'}
# {'id': 7289, 'site': 22, 'type': 'factor', 'factor': 1.15, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:48.743774+00:00\n'}
# {'id': 7290, 'site': 22, 'type': 'cut', 'factor': None, 'level': 16500, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:49.393759+00:00\n'}
# {'id': 7291, 'site': 35, 'type': 'factor', 'factor': 1.1, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:50.100761+00:00\n'}
# {'id': 7292, 'site': 35, 'type': 'cut', 'factor': None, 'level': 2000, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:50.752394+00:00\n'}
# {'id': 7293, 'site': 36, 'type': 'factor', 'factor': 1.1, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:51.430780+00:00\n'}
# {'id': 7294, 'site': 36, 'type': 'cut', 'factor': None, 'level': 2000, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:52.090179+00:00\n'}
# {'id': 7295, 'site': 29, 'type': 'cut', 'factor': None, 'level': 0, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:52.737108+00:00\n'}
# {'id': 7296, 'site': 30, 'type': 'cut', 'factor': None, 'level': 0, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:53.389799+00:00\n'}
# {'id': 7297, 'site': 2, 'type': 'cut', 'factor': None, 'level': 0, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:54.044125+00:00\n'}
# {'id': 7298, 'site': 37, 'type': 'cut', 'factor': None, 'level': 0, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:54.705924+00:00\n'}
# {'id': 7299, 'site': 38, 'type': 'cut', 'factor': None, 'level': 0, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:55.377756+00:00\n'}
# {'id': 7300, 'site': 39, 'type': 'cut', 'factor': None, 'level': 1500, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:56.049062+00:00\n'}
# {'id': 7301, 'site': 40, 'type': 'factor', 'factor': 1.35, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:56.711059+00:00\n'}
# {'id': 7302, 'site': 40, 'type': 'cut', 'factor': None, 'level': 10200, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:57.382003+00:00\n'}
# {'id': 7303, 'site': 32, 'type': 'factor', 'factor': 1.05, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:58.041941+00:00\n'}
# {'id': 7304, 'site': 32, 'type': 'cut', 'factor': None, 'level': 16100, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:58.693293+00:00\n'}
# {'id': 7305, 'site': 41, 'type': 'factor', 'factor': 1.05, 'level': None, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:27:59.344886+00:00\n'}
# {'id': 7306, 'site': 41, 'type': 'cut', 'factor': None, 'level': 10000, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:28:00.007158+00:00\n'}
# {'id': 7307, 'site': 42, 'type': 'cut', 'factor': None, 'level': 0, 'date': datetime.date(2022, 6, 28), 'from_time_utc': datetime.time(1, 0), 'to_time_utc': datetime.time(19, 0), 'is_valid': True, 'comment': 'Record crated at 2022-06-27T16:28:00.688419+00:00\n'}

# %%
from settings.sites import ceg as sites_list

start_time = dt.datetime(year=2022, month=6, day=27, hour=6, minute=0)
end_time = dt.datetime(year=2022, month=6, day=27, hour=17, minute=0)

# add_correction('Poniativka', start_time, end_time, 'factor', factor=1.2, level=None, repeat=True, engine=engine, metadata=metadata)
# add_correction('Vasylivka', start_time, end_time, 'cut', factor=None, level=1, repeat=True, engine=engine, metadata=metadata)
# add_correction('Stanislavchyk', start_time, end_time, 'cut', factor=None, level=1000, repeat=True, engine=engine, metadata=metadata)
# add_correction('Oleshky_2', start_time, end_time, 'factor', factor=0.5, level=None, repeat=True, engine=engine, metadata=metadata)
# add_correction('Bar', start_time, end_time, 'cut', factor=None, level=5000, repeat=True, engine=engine, metadata=metadata)
# add_correction('Balky', start_time, end_time, 'cut', factor=None, level=6000, repeat=True, engine=engine, metadata=metadata)
# add_correction('Bilozerka',    start_time, end_time, 'cut', factor=None, level=0, repeat=True, engine=engine, metadata=metadata)
add_correction('Yelanets_1',     start_time, end_time, 'cut', factor=None, level=2000, repeat=True, engine=engine, metadata=metadata)
add_correction('Yelanets_2',     start_time, end_time, 'cut', factor=None, level=2000, repeat=True, engine=engine, metadata=metadata)

# %%
correction_list = get_corrections_list(dt.date(year=2022, month=6, day=28), type='=', engine=engine, metadata=metadata)
for correction in correction_list:
    print(correction[:6])
# Out:
# ('Pohrebyshche', 7223, 33, 'factor', 1.1, None)
# ('Pohrebyshche', 7224, 33, 'cut', None, 9050)
# ('Bilashky', 7225, 34, 'factor', 1.05, None)
# ('Bilashky', 7226, 34, 'cut', None, 6050)
# ('Bar', 7227, 5, 'factor', 1.15, None)
# ('Bar', 7228, 5, 'cut', None, 6000)
# ('Balky', 7229, 7, 'factor', 1.1, None)
# ('Balky', 7230, 7, 'cut', None, 7000)
# ('Verkhivka', 7231, 6, 'factor', 1.15, None)
# ('Verkhivka', 7232, 6, 'cut', None, 2600)
# ('Kopaihorod', 7233, 13, 'factor', 1.05, None)
# ('Kopaihorod', 7234, 13, 'cut', None, 6000)
# ('Stanislavchyk', 7235, 12, 'factor', 1.05, None)
# ('Stanislavchyk', 7236, 12, 'cut', None, 7900)
# ('Sharhorod_1', 7237, 8, 'factor', 1.15, None)
# ('Sharhorod_1', 7238, 8, 'cut', None, 7000)
# ('Hnatkiv', 7239, 50, 'factor', 1.25, None)
# ('Hnatkiv', 7240, 50, 'cut', None, 4600)
# ('Porohy', 7241, 48, 'factor', 1.2, None)
# ('Porohy', 7242, 48, 'cut', None, 4000)
# ('Hlybochok_1', 7243, 16, 'factor', 1.2, None)
# ('Hlybochok_1', 7244, 16, 'cut', None, 1370)
# ('Hlybochok_2.1', 7245, 17, 'factor', 1.2, None)
# ('Hlybochok_2.1', 7246, 17, 'cut', None, 2470)
# ('Hlybochok_2.2', 7247, 18, 'factor', 1.1, None)
# ('Hlybochok_2.2', 7248, 18, 'cut', None, 3200)
# ('Cherniatka', 7249, 14, 'factor', 1.2, None)
# ('Cherniatka', 7250, 14, 'cut', None, 7000)
# ('Chechelnyk_1', 7251, 10, 'factor', 1.05, None)
# ('Chechelnyk_1', 7252, 10, 'cut', None, 7820)
# ('Chechelnyk_2', 7253, 11, 'factor', 1.05, None)
# ('Chechelnyk_2', 7254, 11, 'cut', None, 7900)
# ('Komyshany_1', 7255, 20, 'factor', 1.25, None)
# ('Komyshany_1', 7256, 20, 'cut', None, 4900)
# ('Komyshany_2', 7257, 21, 'factor', 1.2, None)
# ('Komyshany_2', 7258, 21, 'cut', None, 4000)
# ('Bilozerka', 7259, 15, 'factor', 1.2, None)
# ('Bilozerka', 7260, 15, 'cut', None, 9000)
# ('Myroliubivka', 7261, 1, 'cut', None, 0)
# ('Kyselivka', 7262, 3, 'cut', None, 0)
# ('Oleshky_1', 7263, 28, 'factor', 1.15, None)
# ('Oleshky_1', 7264, 28, 'cut', None, 16000)
# ('Oleshky_2', 7265, 27, 'factor', 1.15, None)
# ('Oleshky_2', 7266, 27, 'cut', None, 15000)
# ('Poniativka', 7267, 4, 'factor', 1.15, None)
# ('Poniativka', 7268, 4, 'cut', None, 14500)
# ('Kostohryzove', 7269, 9, 'factor', 1.3, None)
# ('Kostohryzove', 7270, 9, 'cut', None, 14500)
# ('Veliton', 7271, 24, 'factor', 1.75, None)
# ('Veliton', 7272, 24, 'cut', None, 2300)
# ('Velihen', 7273, 23, 'factor', 1.7, None)
# ('Velihen', 7274, 23, 'cut', None, 5500)
# ('Mykolaivka', 7275, 19, 'factor', 1.25, None)
# ('Mykolaivka', 7276, 19, 'cut', None, 4300)
# ('Rubanivka', 7277, 26, 'factor', 1.35, None)
# ('Rubanivka', 7278, 26, 'cut', None, 16000)
# ('Mala_Lepetykha', 7279, 25, 'factor', 1.2, None)
# ('Mala_Lepetykha', 7280, 25, 'cut', None, 4750)
# ('Kachkarivka', 7281, 47, 'factor', 0.8, None)
# ('Kachkarivka', 7282, 47, 'cut', None, 3500)
# ('Liubymivka', 7283, 31, 'factor', 1.25, None)
# ('Liubymivka', 7284, 31, 'cut', None, 9000)
# ('Vasylivka', 7285, 46, 'factor', 1.25, None)
# ('Vasylivka', 7286, 46, 'cut', None, 38000)
# ('Kulevcha', 7287, 49, 'factor', 1.25, None)
# ('Kulevcha', 7288, 49, 'cut', None, 7900)
# ('Dibrovka', 7289, 22, 'factor', 1.15, None)
# ('Dibrovka', 7290, 22, 'cut', None, 16500)
# ('Yelanets_1', 7291, 35, 'factor', 1.1, None)
# ('Yelanets_1', 7292, 35, 'cut', None, 2000)
# ('Yelanets_2', 7293, 36, 'factor', 1.1, None)
# ('Yelanets_2', 7294, 36, 'cut', None, 2000)
# ('Afanasiivka', 7295, 29, 'cut', None, 0)
# ('Bazaltova', 7296, 30, 'cut', None, 0)
# ('Novokondakove', 7297, 2, 'cut', None, 0)
# ('Inhulets_1', 7298, 37, 'cut', None, 0)
# ('Inhulets_2', 7299, 38, 'cut', None, 0)
# ('Bereznehuvate', 7300, 39, 'cut', None, 1500)
# ('Teplychna', 7301, 40, 'factor', 1.35, None)
# ('Teplychna', 7302, 40, 'cut', None, 10200)
# ('Balivka', 7303, 32, 'factor', 1.05, None)
# ('Balivka', 7304, 32, 'cut', None, 16100)
# ('Solone', 7305, 41, 'factor', 1.05, None)
# ('Solone', 7306, 41, 'cut', None, 10000)
# ('Stepnohirsk', 7307, 42, 'cut', None, 0)
